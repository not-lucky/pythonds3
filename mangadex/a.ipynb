# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"S:\Everything\mca3\nba.csv")

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df[df.isna().any(axis=1)]
# Out:
#                  Name            Team  Number Position   Age Height  Weight  \
# 2        John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 4       Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5        Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 15   Bojan Bogdanovic   Brooklyn Nets    44.0       SG  27.0    6-8   216.0
# 20     Sergey Karasev   Brooklyn Nets    10.0       SG  22.0    6-7   208.0
# ..                ...             ...     ...      ...   ...    ...     ...
# 447       Rudy Gobert       Utah Jazz    27.0        C  23.0    7-1   245.0
# 450        Joe Ingles       Utah Jazz     2.0       SF  28.0    6-8   226.0
# 454         Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455      Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 457               NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College      Salary
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %%
df[df['Position'] == 'SG']['Age'].mean()
# Out:
# 26.20689655172414

# %%
df.sort_values(by="Weight").plot(x='Weight', y='Age', kind='line', label='Line plot')
df.plot(x='Age', y='Weight', kind='scatter', label='Scatter plot')
plt.legend()
plt.show()

# %%
sns.lineplot(x='Age', y='Weight', data=df)
plt.show()

# %%
sns.boxplot(x=df['Age'])
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Age'], y=df['Weight'])
plt.show()

# %%
df = pd.read_excel(r"C:\Users\lucky\Downloads\coalpublic2013.xls")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File s:\Softwares\Scoop\apps\python\current\Lib\site-packages\pandas\compat\_optional.py:132, in import_optional_dependency(name, extra, errors, min_version)
#     131 try:
# --> 132     module = importlib.import_module(name)
#     133 except ImportError:
#
# File s:\Softwares\Scoop\apps\python\current\Lib\importlib\__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1381, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1354, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1318, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'xlrd'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
df = pd.read_excel(r"C:\Users\lucky\Downloads\coalpublic2013.xls", skiprows=3)

# %%
df
# Out:
#       Year  MSHA ID                       Mine Name       Mine State  \
# 0     2013   103381            Tacoa Highwall Miner          Alabama
# 1     2013   103404                Reid School Mine          Alabama
# 2     2013   100759  North River #1 Underground Min          Alabama
# 3     2013   103246                      Bear Creek          Alabama
# 4     2013   103451                     Knight Mine          Alabama
# ...    ...      ...                             ...              ...
# 1445  2013  1103254                   Fidelity Mine  Refuse Recovery
# 1446  2013  1102636                             Wfi  Refuse Recovery
# 1447  2013  4407233                        Gobco #8  Refuse Recovery
# 1448  2013  1518524               Turkey Pen Refuse  Refuse Recovery
# 1449  2013  1519685           Fedscreek Refuse Pile  Refuse Recovery
#
#      Mine County                         Mine Status    Mine Type  \
# 0           Bibb  Active, men working, not producing      Surface
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#       Year  MSHA ID                       Mine Name       Mine State  \
# 0     2013   103381            Tacoa Highwall Miner          Alabama
# 1     2013   103404                Reid School Mine          Alabama
# 2     2013   100759  North River #1 Underground Min          Alabama
# 3     2013   103246                      Bear Creek          Alabama
# 4     2013   103451                     Knight Mine          Alabama
# ...    ...      ...                             ...              ...
# 1445  2013  1103254                   Fidelity Mine  Refuse Recovery
# 1446  2013  1102636                             Wfi  Refuse Recovery
# 1447  2013  4407233                        Gobco #8  Refuse Recovery
# 1448  2013  1518524               Turkey Pen Refuse  Refuse Recovery
# 1449  2013  1519685           Fedscreek Refuse Pile  Refuse Recovery
#
#      Mine County                         Mine Status    Mine Type  \
# 0           Bibb  Active, men working, not producing      Surface
# ...

# %%
print("Sum: ", df["Production (short tons)"].sum())
print("Mean: ", df["Production (short tons)"].mean())
print("Maximum: ", df["Production (short tons)"].max())
print("Minimum: ", df["Production (short tons)"].min())
# Out:
# Sum:  984841779
# Mean:  679201.2268965517
# Maximum:  111005549
# Minimum:  0

# %%
new_df = pd.read_excel(r"C:\Users\lucky\Downloads\coalpublic2013.xls", skiprows=20)

# %%
new_df
# Out:
#       2013   103432                  Skelton Creek          Alabama  \
# 0     2013   103437        Black Warrior Mine No 1          Alabama
# 1     2013   102976  Piney Woods Preparation Plant          Alabama
# 2     2013   102976  Piney Woods Preparation Plant          Alabama
# 3     2013   103380                         Calera          Alabama
# 4     2013   103380                         Calera          Alabama
# ...    ...      ...                            ...              ...
# 1428  2013  1103254                  Fidelity Mine  Refuse Recovery
# 1429  2013  1102636                            Wfi  Refuse Recovery
# 1430  2013  4407233                       Gobco #8  Refuse Recovery
# 1431  2013  1518524              Turkey Pen Refuse  Refuse Recovery
# 1432  2013  1519685          Fedscreek Refuse Pile  Refuse Recovery
#
#       Jefferson                  Temporarily closed      Surface  \
# 0     Jefferson                              Active      Surface
# ...

# %%
df.groupby('MSHA ID')[['Labor Hours']].sum()
# Out:
#          Labor Hours
# MSHA ID
# 100329        144002
# 100347        215295
# 100515          6240
# 100759        474784
# 100851       1001809
# ...              ...
# 4801353      2811138
# 4801429       161270
# 4801645        35687
# 4801646       661265
# 5000030       286079
#
# [1321 rows x 1 columns]

# %%
df[df['Mine Name'].str.startswith('P')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# s:\Everything\pythonds3\mangadex\a.ipynb Cell 23 line 1
# ----> <a href='vscode-notebook-cell:/s%3A/Everything/pythonds3/mangadex/a.ipynb#X43sZmlsZQ%3D%3D?line=0'>1</a> df[df['Mine Name'].str.startswith('P')]
#
# File s:\Softwares\Scoop\apps\python\current\Lib\site-packages\pandas\core\frame.py:3886, in DataFrame.__getitem__(self, key)
#    3883     return self.where(key)
#    3885 # Do we have a (boolean) 1d indexer?
# -> 3886 if com.is_bool_indexer(key):
#    3887     return self._getitem_bool_array(key)
#    3889 # We are left with two options: a single key, and a collection of keys,
#    3890 # We interpret tuples as collections only for non-MultiIndex
#
# File s:\Softwares\Scoop\apps\python\current\Lib\site-packages\pandas\core\common.py:133, in is_bool_indexer(key)
# ...

# %%
df[df['Mine Name'].str.startswith('P').fillna(False)]
# Out:
#       Year  MSHA ID                      Mine Name                Mine State  \
# 13    2013   103332                  Powhatan Mine                   Alabama
# 18    2013   102976  Piney Woods Preparation Plant                   Alabama
# 19    2013   102976  Piney Woods Preparation Plant                   Alabama
# 46    2013   103321                 Poplar Springs                   Alabama
# 50    2013   301569                       Penny #1                  Arkansas
# ...    ...      ...                            ...                       ...
# 1389  2013  4605868     Pinnacle Preparation Plant  West Virginia (Southern)
# 1424  2013  4605995         Preparation Plant No 1           Refuse Recovery
# 1437  2013  3610027                  Paradise Bank           Refuse Recovery
# 1438  2013  3609304         Park Mine Coal Company           Refuse Recovery
# 1440  2013  3609405                        Phoenix           Refuse Recovery
#
# ...
